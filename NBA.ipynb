# %%
#program to obtain multiple years of data from site
years = [2019, 2020, 2021, 2022, 2023]
url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

for year in years : 
    url_link = url.format(year)
    print(url_link)
# Out:
# https://www.basketball-reference.com/leagues/NBA_2019_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2021_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2022_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2023_per_game.html

# %%
import pandas as pd

# %%
#scrape data from url into pandas data frame
df = pd.read_html(url_link, header = 0)[0]
df.head(25)
# Out:
#     Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1          Precious Achiuwa    C   23  TOR  55  12  20.7   3.6   7.3
# 1    2              Steven Adams    C   29  MEM  42  42  27.0   3.7   6.3
# 2    3               Bam Adebayo    C   25  MIA  75  75  34.6   8.0  14.9
# 3    4              Ochai Agbaji   SG   22  UTA  59  22  20.5   2.8   6.5
# 4    5              Santi Aldama   PF   22  MEM  77  20  21.8   3.2   6.8
# 5    6  Nickeil Alexander-Walker   SG   24  TOT  59   3  15.0   2.2   5.0
# 6    6  Nickeil Alexander-Walker   SG   24  UTA  36   3  14.7   2.3   4.7
# 7    6  Nickeil Alexander-Walker   SG   24  MIN  23   0  15.5   2.1   5.4
# 8    7             Grayson Allen   SG   27  MIL  72  70  27.4   3.4   7.7
# 9    8             Jarrett Allen    C   24  CLE  68  68  32.6   5.9   9.2
# 10   9             Jose Alvarado   PG   24  NOP  61  10  21.5   3.3   8.0
# 11  10             Kyle Anderson   PF   29  MIN  69  46  28.4   3.7   7.2
# 12  11     Giannis Antetokounmpo   PF   28  MIL  63  63  32.1  11.2  20.3
# 13  12    Thanasis Antetokounmpo   PF   30  MIL  37   0   5.6   0.5   1.2
# 14  13              Cole Anthony   PG   22  ORL  60   4  25.9   4.6  10.2
# 15  14                OG Anunoby   SF   25  TOR  67  67  35.6   6.3  13.2
# 16  15          Ryan Arcidiacono   PG   28  TOT  20   4   8.6   0.5   1.9
# 17  15          Ryan Arcidiacono   PG   28  NYK  11   0   2.4   0.1   0.5
# 18  15          Ryan Arcidiacono   PG   28  POR   9   4  16.2   0.9   3.6
# 19  16               Deni Avdija   SF   22  WAS  76  40  26.6   3.3   7.6
# 20  17             Deandre Ayton    C   24  PHO  67  67  30.4   7.8  13.2
# 21  18            Udoka Azubuike    C   23  UTA  36   4  10.0   1.6   2.0
# 22  19         Marvin Bagley III    C   23  DET  42  25  23.6   4.8   9.1
# 23  20       Patrick Baldwin Jr.   SF   20  GSW  31   0   7.3   1.4   3.5
# 24  Rk                    Player  Pos  Age   Tm   G  GS    MP    FG   FGA
#
#     ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...  .702  1.8  4.1   6.0  0.9  0.6  0.5  1.1  1.9   9.2
# 1   ...  .364  5.1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2   ...  .806  2.5  6.7   9.2  3.2  1.2  0.8  2.5  2.8  20.4
# 3   ...  .812  0.7  1.3   2.1  1.1  0.3  0.3  0.7  1.7   7.9
# 4   ...  .750  1.1  3.7   4.8  1.3  0.6  0.6  0.8  1.9   9.0
# 5   ...  .667  0.3  1.5   1.7  1.8  0.5  0.4  0.9  1.5   6.2
# 6   ...  .692  0.2  1.4   1.6  2.1  0.7  0.4  1.3  1.6   6.3
# 7   ...  .619  0.3  1.5   1.8  1.4  0.3  0.3  0.4  1.3   5.9
# 8   ...  .905  0.8  2.4   3.3  2.3  0.9  0.2  1.0  1.6  10.4
# 9   ...  .733  3.3  6.5   9.8  1.7  0.8  1.2  1.4  2.3  14.3
# 10  ...  .813  0.5  1.9   2.3  3.0  1.1  0.2  1.3  2.0   9.0
# 11  ...  .735  1.0  4.4   5.3  4.9  1.1  0.9  1.5  2.1   9.4
# 12  ...  .645  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1
# 13  ...  .500  0.4  0.8   1.2  0.4  0.1  0.1  0.3  0.6   1.4
# 14  ...  .894  0.8  4.0   4.8  3.9  0.6  0.5  1.5  2.6  13.0
# 15  ...  .838  1.4  3.5   5.0  2.0  1.9  0.7  2.0  3.0  16.8
# 16  ...   NaN  0.0  0.8   0.8  1.2  0.3  0.0  0.4  0.9   1.3
# 17  ...   NaN  0.0  0.4   0.4  0.2  0.2  0.0  0.1  0.3   0.3
# 18  ...   NaN  0.0  1.2   1.2  2.3  0.3  0.0  0.7  1.6   2.6
# 19  ...  .739  1.0  5.4   6.4  2.8  0.9  0.4  1.6  2.8   9.2
# 20  ...  .760  2.6  7.4  10.0  1.7  0.6  0.8  1.8  2.8  18.0
# 21  ...  .350  0.9  2.4   3.3  0.3  0.2  0.4  0.5  0.9   3.5
# 22  ...  .750  2.2  4.2   6.4  0.9  0.5  0.7  1.1  1.9  12.0
# 23  ...  .667  0.0  1.3   1.3  0.4  0.2  0.1  0.4  0.5   3.9
# 24  ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#
# [25 rows x 30 columns]

# %%
#drop rows with headers and reset the index
df.drop(df[df.Age == 'Age'].index, inplace = True)
df.reset_index()
df.head(25)
# Out:
#     Rk                    Player Pos Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0    1          Precious Achiuwa   C  23  TOR  55  12  20.7   3.6   7.3  ...
# 1    2              Steven Adams   C  29  MEM  42  42  27.0   3.7   6.3  ...
# 2    3               Bam Adebayo   C  25  MIA  75  75  34.6   8.0  14.9  ...
# 3    4              Ochai Agbaji  SG  22  UTA  59  22  20.5   2.8   6.5  ...
# 4    5              Santi Aldama  PF  22  MEM  77  20  21.8   3.2   6.8  ...
# 5    6  Nickeil Alexander-Walker  SG  24  TOT  59   3  15.0   2.2   5.0  ...
# 6    6  Nickeil Alexander-Walker  SG  24  UTA  36   3  14.7   2.3   4.7  ...
# 7    6  Nickeil Alexander-Walker  SG  24  MIN  23   0  15.5   2.1   5.4  ...
# 8    7             Grayson Allen  SG  27  MIL  72  70  27.4   3.4   7.7  ...
# 9    8             Jarrett Allen   C  24  CLE  68  68  32.6   5.9   9.2  ...
# 10   9             Jose Alvarado  PG  24  NOP  61  10  21.5   3.3   8.0  ...
# 11  10             Kyle Anderson  PF  29  MIN  69  46  28.4   3.7   7.2  ...
# 12  11     Giannis Antetokounmpo  PF  28  MIL  63  63  32.1  11.2  20.3  ...
# 13  12    Thanasis Antetokounmpo  PF  30  MIL  37   0   5.6   0.5   1.2  ...
# 14  13              Cole Anthony  PG  22  ORL  60   4  25.9   4.6  10.2  ...
# 15  14                OG Anunoby  SF  25  TOR  67  67  35.6   6.3  13.2  ...
# 16  15          Ryan Arcidiacono  PG  28  TOT  20   4   8.6   0.5   1.9  ...
# 17  15          Ryan Arcidiacono  PG  28  NYK  11   0   2.4   0.1   0.5  ...
# 18  15          Ryan Arcidiacono  PG  28  POR   9   4  16.2   0.9   3.6  ...
# 19  16               Deni Avdija  SF  22  WAS  76  40  26.6   3.3   7.6  ...
# 20  17             Deandre Ayton   C  24  PHO  67  67  30.4   7.8  13.2  ...
# 21  18            Udoka Azubuike   C  23  UTA  36   4  10.0   1.6   2.0  ...
# 22  19         Marvin Bagley III   C  23  DET  42  25  23.6   4.8   9.1  ...
# 23  20       Patrick Baldwin Jr.  SF  20  GSW  31   0   7.3   1.4   3.5  ...
# 25  21               LaMelo Ball  PG  21  CHO  36  36  35.2   8.2  20.0  ...
#
#      FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   .702  1.8  4.1   6.0  0.9  0.6  0.5  1.1  1.9   9.2
# 1   .364  5.1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2   .806  2.5  6.7   9.2  3.2  1.2  0.8  2.5  2.8  20.4
# 3   .812  0.7  1.3   2.1  1.1  0.3  0.3  0.7  1.7   7.9
# 4   .750  1.1  3.7   4.8  1.3  0.6  0.6  0.8  1.9   9.0
# 5   .667  0.3  1.5   1.7  1.8  0.5  0.4  0.9  1.5   6.2
# 6   .692  0.2  1.4   1.6  2.1  0.7  0.4  1.3  1.6   6.3
# 7   .619  0.3  1.5   1.8  1.4  0.3  0.3  0.4  1.3   5.9
# 8   .905  0.8  2.4   3.3  2.3  0.9  0.2  1.0  1.6  10.4
# 9   .733  3.3  6.5   9.8  1.7  0.8  1.2  1.4  2.3  14.3
# 10  .813  0.5  1.9   2.3  3.0  1.1  0.2  1.3  2.0   9.0
# 11  .735  1.0  4.4   5.3  4.9  1.1  0.9  1.5  2.1   9.4
# 12  .645  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1
# 13  .500  0.4  0.8   1.2  0.4  0.1  0.1  0.3  0.6   1.4
# 14  .894  0.8  4.0   4.8  3.9  0.6  0.5  1.5  2.6  13.0
# 15  .838  1.4  3.5   5.0  2.0  1.9  0.7  2.0  3.0  16.8
# 16   NaN  0.0  0.8   0.8  1.2  0.3  0.0  0.4  0.9   1.3
# 17   NaN  0.0  0.4   0.4  0.2  0.2  0.0  0.1  0.3   0.3
# 18   NaN  0.0  1.2   1.2  2.3  0.3  0.0  0.7  1.6   2.6
# 19  .739  1.0  5.4   6.4  2.8  0.9  0.4  1.6  2.8   9.2
# 20  .760  2.6  7.4  10.0  1.7  0.6  0.8  1.8  2.8  18.0
# 21  .350  0.9  2.4   3.3  0.3  0.2  0.4  0.5  0.9   3.5
# 22  .750  2.2  4.2   6.4  0.9  0.5  0.7  1.1  1.9  12.0
# 23  .667  0.0  1.3   1.3  0.4  0.2  0.1  0.4  0.5   3.9
# 25  .836  1.2  5.3   6.4  8.4  1.3  0.3  3.6  3.3  23.3
#
# [25 rows x 30 columns]

# %%
#change data type of numeric columns
df[['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']] = df[['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].apply(pd.to_numeric, errors = 'coerce')
df.dtypes
# Out:
# Rk         object
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
import seaborn as sns

# %%
# plot the distribution of points
sns.distplot(df.PTS, 
             kde = False, 
            hist_kws = dict(edgecolor = 'black', 
                           linewidth = 2), 
            color = '#00BFC4')
# Out:
# C:\Users\Austin\AppData\Local\Temp\ipykernel_6964\1639497366.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.PTS,
# <Axes: xlabel='PTS'>

# %%
#style data frame fonts and colors using CSS
df.head(25).style.set_table_styles(
[{'selector' : 'th', 
     'props' : [('background', '#7CAE00'), 
               ('color', 'white'), 
               ('font-family', 'verdana')]}, 
{'selector' : 'td', 
    'props' : [('font-family', 'verdana')]}, 
{'selector' : 'tr:nth-of-type(odd)', 
    'props' : [('background', '#DCDCDC')]}, 
{'selector' : 'tr:nth-of-type(even)', 
    'props' : [('background', 'white')]},
{'selector' : 'tr:hover', 
    'props' : [('background-color', 'yellow')]}
]
)
# Out:
# <style type="text/css">
# #T_42a1a th {
#   background: #7CAE00;
#   color: white;
#   font-family: verdana;
# }
# #T_42a1a td {
#   font-family: verdana;
# }
# #T_42a1a tr:nth-of-type(odd) {
#   background: #DCDCDC;
# }
# #T_42a1a tr:nth-of-type(even) {
#   background: white;
# }
# #T_42a1a tr:hover {
#   background-color: yellow;
# }
# </style>
# <table id="T_42a1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42a1a_level0_col0" class="col_heading level0 col0" >Rk</th>
#       <th id="T_42a1a_level0_col1" class="col_heading level0 col1" >Player</th>
#       <th id="T_42a1a_level0_col2" class="col_heading level0 col2" >Pos</th>
#       <th id="T_42a1a_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_42a1a_level0_col4" class="col_heading level0 col4" >Tm</th>
#       <th id="T_42a1a_level0_col5" class="col_heading level0 col5" >G</th>
#       <th id="T_42a1a_level0_col6" class="col_heading level0 col6" >GS</th>
#       <th id="T_42a1a_level0_col7" class="col_heading level0 col7" >MP</th>
#       <th id="T_42a1a_level0_col8" class="col_heading level0 col8" >FG</th>
#       <th id="T_42a1a_level0_col9" class="col_heading level0 col9" >FGA</th>
#       <th id="T_42a1a_level0_col10" class="col_heading level0 col10" >FG%</th>
#       <th id="T_42a1a_level0_col11" class="col_heading level0 col11" >3P</th>
#       <th id="T_42a1a_level0_col12" class="col_heading level0 col12" >3PA</th>
#       <th id="T_42a1a_level0_col13" class="col_heading level0 col13" >3P%</th>
#       <th id="T_42a1a_level0_col14" class="col_heading level0 col14" >2P</th>
#       <th id="T_42a1a_level0_col15" class="col_heading level0 col15" >2PA</th>
#       <th id="T_42a1a_level0_col16" class="col_heading level0 col16" >2P%</th>
#       <th id="T_42a1a_level0_col17" class="col_heading level0 col17" >eFG%</th>
#       <th id="T_42a1a_level0_col18" class="col_heading level0 col18" >FT</th>
#       <th id="T_42a1a_level0_col19" class="col_heading level0 col19" >FTA</th>
#       <th id="T_42a1a_level0_col20" class="col_heading level0 col20" >FT%</th>
#       <th id="T_42a1a_level0_col21" class="col_heading level0 col21" >ORB</th>
#       <th id="T_42a1a_level0_col22" class="col_heading level0 col22" >DRB</th>
#       <th id="T_42a1a_level0_col23" class="col_heading level0 col23" >TRB</th>
#       <th id="T_42a1a_level0_col24" class="col_heading level0 col24" >AST</th>
#       <th id="T_42a1a_level0_col25" class="col_heading level0 col25" >STL</th>
#       <th id="T_42a1a_level0_col26" class="col_heading level0 col26" >BLK</th>
#       <th id="T_42a1a_level0_col27" class="col_heading level0 col27" >TOV</th>
#       <th id="T_42a1a_level0_col28" class="col_heading level0 col28" >PF</th>
#       <th id="T_42a1a_level0_col29" class="col_heading level0 col29" >PTS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42a1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42a1a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_42a1a_row0_col1" class="data row0 col1" >Precious Achiuwa</td>
#       <td id="T_42a1a_row0_col2" class="data row0 col2" >C</td>
#       <td id="T_42a1a_row0_col3" class="data row0 col3" >23</td>
#       <td id="T_42a1a_row0_col4" class="data row0 col4" >TOR</td>
#       <td id="T_42a1a_row0_col5" class="data row0 col5" >55</td>
#       <td id="T_42a1a_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_42a1a_row0_col7" class="data row0 col7" >20.700000</td>
#       <td id="T_42a1a_row0_col8" class="data row0 col8" >3.600000</td>
#       <td id="T_42a1a_row0_col9" class="data row0 col9" >7.300000</td>
#       <td id="T_42a1a_row0_col10" class="data row0 col10" >0.485000</td>
#       <td id="T_42a1a_row0_col11" class="data row0 col11" >0.500000</td>
#       <td id="T_42a1a_row0_col12" class="data row0 col12" >2.000000</td>
#       <td id="T_42a1a_row0_col13" class="data row0 col13" >0.269000</td>
#       <td id="T_42a1a_row0_col14" class="data row0 col14" >3.000000</td>
#       <td id="T_42a1a_row0_col15" class="data row0 col15" >5.400000</td>
#       <td id="T_42a1a_row0_col16" class="data row0 col16" >0.564000</td>
#       <td id="T_42a1a_row0_col17" class="data row0 col17" >0.521000</td>
#       <td id="T_42a1a_row0_col18" class="data row0 col18" >1.600000</td>
#       <td id="T_42a1a_row0_col19" class="data row0 col19" >2.300000</td>
#       <td id="T_42a1a_row0_col20" class="data row0 col20" >0.702000</td>
#       <td id="T_42a1a_row0_col21" class="data row0 col21" >1.800000</td>
#       <td id="T_42a1a_row0_col22" class="data row0 col22" >4.100000</td>
#       <td id="T_42a1a_row0_col23" class="data row0 col23" >6.000000</td>
#       <td id="T_42a1a_row0_col24" class="data row0 col24" >0.900000</td>
#       <td id="T_42a1a_row0_col25" class="data row0 col25" >0.600000</td>
#       <td id="T_42a1a_row0_col26" class="data row0 col26" >0.500000</td>
#       <td id="T_42a1a_row0_col27" class="data row0 col27" >1.100000</td>
#       <td id="T_42a1a_row0_col28" class="data row0 col28" >1.900000</td>
#       <td id="T_42a1a_row0_col29" class="data row0 col29" >9.200000</td>
#     </tr>
#     <tr>
#       <th id="T_42a1a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42a1a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_42a1a_row1_col1" class="data row1 col1" >Steven Adams</td>
#       <td id="T_42a1a_row1_col2" class="data row1 col2" >C</td>
#       <td id="T_42a1a_row1_col3" class="data row1 col3" >29</td>
#       <td id="T_42a1a_row1_col4" class="data row1 col4" >MEM</td>
#       <td id="T_42a1a_row1_col5" class="data row1 col5" >42</td>
#       <td id="T_42a1a_row1_col6" class="data row1 col6" >42</td>
#       <td id="T_42a1a_row1_col7" class="data row1 col7" >27.000000</td>
#       <td id="T_42a1a_row1_col8" class="data row1 col8" >3.700000</td>
#       <td id="T_42a1a_row1_col9" class="data row1 col9" >6.300000</td>
#       <td id="T_42a1a_row1_col10" class="data row1 col10" >0.597000</td>
#       <td id="T_42a1a_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_42a1a_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_42a1a_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_42a1a_row1_col14" class="data row1 col14" >3.700000</td>
#       <td id="T_42a1a_row1_col15" class="data row1 col15" >6.200000</td>
#       <td id="T_42a1a_row1_col16" class="data row1 col16" >0.599000</td>
#       <td id="T_42a1a_row1_col17" class="data row1 col17" >0.597000</td>
#       <td id="T_42a1a_row1_col18" class="data row1 col18" >1.100000</td>
#       <td id="T_42a1a_row1_col19" class="data row1 col19" >3.100000</td>
#       <td id="T_42a1a_row1_col20" class="data row1 col20" >0.364000</td>
#       <td id="T_42a1a_row1_col21" class="data row1 col21" >5.100000</td>
#       <td id="T_42a1a_row1_col22" class="data row1 col22" >6.500000</td>
#       <td id="T_42a1a_row1_col23" class="data row1 col23" >11.500000</td>
#       <td id="T_42a1a_row1_col24" class="data row1 col24" >2.300000</td>
#       <td id="T_42a1a_row1_col25" class="data row1 col25" >0.900000</td>
#       <td id="T_42a1a_row1_col26" class="data row1 col26" >1.100000</td>
#       <td id="T_42a1a_row1_col27" class="data row1 col27" >1.900000</td>
#       <td id="T_42a1a_row1_col28" class="data row1 col28" >2.300000</td>
#       <td id="T_42a1a_row1_col29" class="data row1 col29" >8.600000</td>
#     </tr>
#     <tr>
#       <th id="T_42a1a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42a1a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_42a1a_row2_col1" class="data row2 col1" >Bam Adebayo</td>
#       <td id="T_42a1a_row2_col2" class="data row2 col2" >C</td>
#       <td id="T_42a1a_row2_col3" class="data row2 col3" >25</td>
#       <td id="T_42a1a_row2_col4" class="data row2 col4" >MIA</td>
#       <td id="T_42a1a_row2_col5" class="data row2 col5" >75</td>
#       <td id="T_42a1a_row2_col6" class="data row2 col6" >75</td>
#       <td id="T_42a1a_row2_col7" class="data row2 col7" >34.600000</td>
#       <td id="T_42a1a_row2_col8" class="data row2 col8" >8.000000</td>
#       <td id="T_42a1a_row2_col9" class="data row2 col9" >14.900000</td

# %%
#color point totals by given ranges
def color_red(val) : 
    if val > 20 : 
        color = 'green'
    elif val > 5 : 
        color = 'red'
    else : 
        color = 'black'
    return 'color: %s' % color
df[['PTS']].head(25).style.applymap(color_red)
# Out:
# <style type="text/css">
# #T_7a71b_row0_col0, #T_7a71b_row1_col0, #T_7a71b_row3_col0, #T_7a71b_row4_col0, #T_7a71b_row5_col0, #T_7a71b_row6_col0, #T_7a71b_row7_col0, #T_7a71b_row8_col0, #T_7a71b_row9_col0, #T_7a71b_row10_col0, #T_7a71b_row11_col0, #T_7a71b_row14_col0, #T_7a71b_row15_col0, #T_7a71b_row19_col0, #T_7a71b_row20_col0, #T_7a71b_row22_col0 {
#   color: red;
# }
# #T_7a71b_row2_col0, #T_7a71b_row12_col0, #T_7a71b_row24_col0 {
#   color: green;
# }
# #T_7a71b_row13_col0, #T_7a71b_row16_col0, #T_7a71b_row17_col0, #T_7a71b_row18_col0, #T_7a71b_row21_col0, #T_7a71b_row23_col0 {
#   color: black;
# }
# </style>
# <table id="T_7a71b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a71b_level0_col0" class="col_heading level0 col0" >PTS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a71b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a71b_row0_col0" class="data row0 col0" >9.200000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a71b_row1_col0" class="data row1 col0" >8.600000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a71b_row2_col0" class="data row2 col0" >20.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a71b_row3_col0" class="data row3 col0" >7.900000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a71b_row4_col0" class="data row4 col0" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a71b_row5_col0" class="data row5 col0" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a71b_row6_col0" class="data row6 col0" >6.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a71b_row7_col0" class="data row7 col0" >5.900000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a71b_row8_col0" class="data row8 col0" >10.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a71b_row9_col0" class="data row9 col0" >14.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a71b_row10_col0" class="data row10 col0" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a71b_row11_col0" class="data row11 col0" >9.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7a71b_row12_col0" class="data row12 col0" >31.100000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7a71b_row13_col0" class="data row13 col0" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7a71b_row14_col0" class="data row14 col0" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7a71b_row15_col0" class="data row15 col0" >16.800000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7a71b_row16_col0" class="data row16 col0" >1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7a71b_row17_col0" class="data row17 col0" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7a71b_row18_col0" class="data row18 col0" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7a71b_row19_col0" class="data row19 col0" >9.200000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7a71b_row20_col0" class="data row20 col0" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7a71b_row21_col0" class="data row21 col0" >3.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7a71b_row22_col0" class="data row22 col0" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7a71b_row23_col0" class="data row23 col0" >3.900000</td>
#     </tr>
#     <tr>
#       <th id="T_7a71b_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_7a71b_row24_col0" class="data row24 col0" >23.300000</td>
#     </tr>
#   </tbody>
# </table>
